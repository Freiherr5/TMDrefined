# %%
import pandas as pd
import numpy as np

# %%
raw60 = pd.read_excel("first_of_top60_scales_raw.xlsx").set_index("AA")
norm_scale = pd.read_excel("scales.xlsx").set_index("AA")

# %%
col60 = raw60.columns.tolist()

# %%
norm60 = norm_scale[col60]
norm60
# Out:
#     ARGP820103  BUNA790103  BURA740102  CHAM820102  CHAM830102  CHAM830103  \
# AA
# A        0.504       0.691       0.264       0.262       0.182         0.0
# C        0.387       0.819       1.000       0.947       0.442         0.5
# D        0.000       0.745       0.213       0.601       0.397         0.5
# E        0.032       0.745       0.186       0.561       0.017         0.5
# F        0.670       1.000       0.354       0.462       0.354         0.5
# G        0.170       0.596       0.336       0.240       0.470         0.0
# H        0.053       0.851       0.000       0.313       0.514         0.5
# I        0.543       0.745       0.634       0.424       0.633         1.0
# K        0.004       0.691       0.195       0.313       0.376         0.5
# L        0.989       0.691       0.601       0.463       0.267         0.5
# M        1.000       0.000       0.526       0.405       0.000         0.5
# ...

# %%
norm60.to_excel("norm_top_of_60.xlsx")
